# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("transformed.csv")
df.head()
# Out:
#                             name scraped_time  on_sale discount
# 0         Samsung Galaxy A54 5G      16/05/23    False      NaN  \
# 1                     Nokia C30      16/05/23     True     -17%
# 2  Nokia G21 Android Smart phone     16/05/23    False      NaN
# 3                 Realme 9i 5G 6     16/05/23    False      NaN
# 4                  Samsung A04e      16/05/23    False      NaN
#
#    original_price  sale_price  average_rating           scores
# 0         59999.0     59999.0             4.0  [0, 1, 0, 0, 0]  \
# 1         11999.0      9999.0             4.8  [3, 1, 0, 0, 0]
# 2         22999.0     22999.0             4.0  [3, 0, 0, 0, 1]
# 3         29999.0     29999.0             5.0  [2, 0, 0, 0, 0]
# 4         12499.0     12499.0             5.0  [1, 0, 0, 0, 0]
#
#                                         review_texts    Brand  ...
# 0                                                NaN  Samsung  ...  \
# ...

# %%
df.columns
# Out:
# Index(['name', 'scraped_time', 'on_sale', 'discount', 'original_price',
#        'sale_price', 'average_rating', 'scores', 'review_texts', 'Brand',
#        'SKU', 'Battery Capacity', 'Screen Size (inches)', 'Build Type',
#        'Camera Front (Megapixels)', 'Camera Back (Megapixels)',
#        'Number Of Cameras', 'Display Protection', 'Model Year',
#        'Network Connections', 'Fast Charging', 'Wireless Charging',
#        'Number of SIM Slots', 'PPI', 'Charger Type', 'Flash',
#        'Bluetooth Support', 'Wi-Fi', 'SIM Type', 'Removable Battery', 'GPS',
#        'FM Radio', 'NFC', 'Fingerprint Sensor', 'Expandable Storage',
#        'Memory Card Slot Type', 'Video Resolution', 'Operating System',
#        'Notchted Display', 'Model', 'Headphone Jack', 'Display Type',
#        'Processor Type', 'Refresh Rate', 'Resolution', 'Warranty Policy EN'],
#       dtype='object')

# %% [markdown]
# ## Brand products count

# %%
brands_count = df['Brand'].value_counts()
plt.bar(brands_count.index, brands_count.values)
plt.xlabel('Brand')
plt.ylabel('Count')
plt.title('Brand Product Counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Price Distribution

# %%
plt.hist(df['sale_price'], bins = 30, edgecolor='black')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Distribution')
plt.xticks(rotation=90)
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))

axes[0, 0].scatter(df['sale_price'], df["average_rating"])
axes[0, 0].set_xlabel('Price')
axes[0, 0].set_ylabel('Average Rating')
axes[0, 0].set_title('Price and rating')

axes[0, 1].scatter(df["Model Year"].fillna("2023"), df['sale_price'])
axes[0, 1].set_xlabel('Built year')
axes[0, 1].set_ylabel('Price')
axes[0, 1].tick_params(axis='x', labelrotation=45)
axes[0, 1].set_title('Built year and price')

axes[1, 0].scatter(df["Battery Capacity"].fillna("Not Specified"), df['sale_price'])
axes[1, 0].set_xlabel('Battery Capacity')
axes[1, 0].set_xlabel('Price')
axes[1, 0].tick_params(axis='x', labelrotation=45)
axes[1, 0].set_title('Battery Capacity and Price')

axes[1, 1].scatter(df['Screen Size (inches)'].fillna("Not Specified"), df["sale_price"])
axes[1, 1].set_xlabel('Screen Size')
axes[1, 1].set_xlabel('Price')
axes[1, 1].tick_params(axis='x', labelrotation=45)
axes[1, 1].set_title('Screen Size and Price')
# Out:
# Text(0.5, 1.0, 'Screen Size and Price')
